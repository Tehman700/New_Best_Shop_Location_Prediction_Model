# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X, Y = make_regression(n_samples=1000, n_features= 2, n_informative=2, n_targets=1, noise =50)

# %%
df = pd.DataFrame({'Feature 1':X[:,0], 'Feature 2':X[:,1], 'Target':Y})

# %%
df.head()
# Out:
#    Feature 1  Feature 2     Target
# 0   0.498499   0.264261 -23.470599
# 1  -0.259446   1.372130   7.376257
# 2  -1.187250   0.049829 -14.763565
# 3   0.412411  -1.035217 -90.564984
# 4  -0.014704   0.056166  27.543398

# %%
df.describe()
# Out:
#          Feature 1    Feature 2       Target
# count  1000.000000  1000.000000  1000.000000
# mean     -0.026581     0.051872     0.700044
# std       1.031955     0.982415    64.093182
# min      -3.086989    -3.051894  -181.496246
# 25%      -0.745907    -0.631354   -42.998355
# 50%      -0.037282     0.024534     1.219142
# 75%       0.656433     0.684512    46.886805
# max       3.191106     3.237773   227.420424

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
#       2 fig.show()
#
# File c:\Users\tehma\OneDrive\Desktop\MLP\.venv\Lib\site-packages\plotly\express\_chart_types.py:791, in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, subtitle, template, width, height)
#     744 def scatter_3d(
#     745     data_frame=None,
#     746     x=None,
#    (...)    785     height=None,
#     786 ) -> go.Figure:
#     787     """
#     788     In a 3D scatter plot, each row of `data_frame` is represented by a
#     789     symbol mark in 3D space.
#     790     """
# --> 791     return make_figure(args=locals(), constructor=go.Scatter3d)
#
# File c:\Users\tehma\OneDrive\Desktop\MLP\.venv\Lib\site-packages\plotly\express\_core.py:2483, in make_figure(args, constructor, trace_patch, layout_patch)
#    2480 layout_patch = layout_patch or {}
#    2481 apply_default_cascade(args)
# -> 2483 args = build_dataframe(args, constructor)
#    2484 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2485     args = process_dataframe_hierarchy(args)
#
# File c:\Users\tehma\OneDrive\Desktop\MLP\.venv\Lib\site-packages\plotly\express\_core.py:1729, in build_dataframe(args, constructor)
#    1726     args["color"] = None
#    1727 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1729 df_output, wide_id_vars = process_args_into_dataframe(
#    1730     args,
#    1731     wide_mode,
#    1732     var_name,
#    1733     value_name,
#    1734     is_pd_like,
#    1735     native_namespace,
#    1736 )
#    1737 df_output: nw.DataFrame
#    1738 # now that `df_output` exists and `args` contains only references, we complete
#    1739 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1740 # df_output
#
# File c:\Users\tehma\OneDrive\Desktop\MLP\.venv\Lib\site-packages\plotly\express\_core.py:1330, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1328         if argument == "index":
#    1329             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1330         raise ValueError(err_msg)
#    1331 elif length and (actual_len := len(df_input)) != length:
#    1332     raise ValueError(
#    1333         "All arguments should have the same length. "
#    1334         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1341         )
#    1342     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['Feature 1', 'Feature 2', 'Target'] but received: feature1
