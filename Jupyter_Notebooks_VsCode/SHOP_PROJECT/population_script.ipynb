# %%
import pandas as pd
url = 'https://www.citypopulation.de/en/pakistan/admin/islamabad/501__islamabad/'

tables = pd.read_html(url)

print(f"Found {len(tables)} tables.")

pop_df = tables[0]
print(pop_df.columns)
print(pop_df.head())

pop_df.to_csv('population_data.csv', index=False)

print("✅ Population data saved as population_data.csv")
# Out:
# Found 7 tables.
# Index(['Name', 'Status', 'Population Census 1972-09-16',
#        'Population Census 1981-03-01', 'Population Census 1998-03-01',
#        'Population Census 2017-03-15', 'Population Census 2023-03-01',
#        'Unnamed: 7'],
#       dtype='object')
#         Name            Status  Population Census 1972-09-16  \
# 0  Islamabad          District                        237549
# 1   Pakistan  Islamic Republic                      65309340
#
#    Population Census 1981-03-01  Population Census 1998-03-01  \
# 0                        340286                        805235
# 1                      84253644                     132352279
#
#    Population Census 2017-03-15  Population Census 2023-03-01  Unnamed: 7
# 0                       2003368                       2363863         NaN
# 1                     207684626                     241499431         NaN
# ✅ Population data saved as population_data.csv
